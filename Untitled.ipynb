# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib


data = pd.read_csv("COVID-19 India Statewise Vaccine Data.csv")
# print(data.head)
# print(data.columns)
# print(data.describe())
sns.relplot(x="Population",y="Total Vaccination Doses",data=data)
sns.set(rc = {'figure.figsize':(10,8)})
