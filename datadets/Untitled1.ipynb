# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from plotly.subplots import make_subplots
from datetime import datetime

# %%
covid_df=pd.read_csv("covid_19_india.csv")

# %%
vaccine_df=pd.read_csv("covid_vaccine_statewise.csv")

# %%
covid_df.drop(["Sno","Time","ConfirmedIndianNational","ConfirmedForeignNational"],inplace=True,axis=1)

# %%
covid_df
# Out:
#              Date State/UnionTerritory    Cured  Deaths  Confirmed
# 0      2020-01-30               Kerala        0       0          1
# 1      2020-01-31               Kerala        0       0          1
# 2      2020-02-01               Kerala        0       0          2
# 3      2020-02-02               Kerala        0       0          3
# 4      2020-02-03               Kerala        0       0          3
# ...           ...                  ...      ...     ...        ...
# 18105  2021-08-11            Telangana   638410    3831     650353
# 18106  2021-08-11              Tripura    77811     773      80660
# 18107  2021-08-11          Uttarakhand   334650    7368     342462
# 18108  2021-08-11        Uttar Pradesh  1685492   22775    1708812
# 18109  2021-08-11          West Bengal  1506532   18252    1534999
#
# [18110 rows x 5 columns]

# %%
covid_df['Date']=pd.to_datetime(covid_df['Date'],format='%Y-%m-%d')

# %%
covid_df
# Out:
#             Date State/UnionTerritory    Cured  Deaths  Confirmed
# 0     2020-01-30               Kerala        0       0          1
# 1     2020-01-31               Kerala        0       0          1
# 2     2020-02-01               Kerala        0       0          2
# 3     2020-02-02               Kerala        0       0          3
# 4     2020-02-03               Kerala        0       0          3
# ...          ...                  ...      ...     ...        ...
# 18105 2021-08-11            Telangana   638410    3831     650353
# 18106 2021-08-11              Tripura    77811     773      80660
# 18107 2021-08-11          Uttarakhand   334650    7368     342462
# 18108 2021-08-11        Uttar Pradesh  1685492   22775    1708812
# 18109 2021-08-11          West Bengal  1506532   18252    1534999
#
# [18110 rows x 5 columns]

# %%
covid_df['Active_Cases']=covid_df['Confirmed']-(covid_df['Cured']+covid_df['Deaths'])

# %%
covid_df
# Out:
#             Date State/UnionTerritory    Cured  Deaths  Confirmed  \
# 0     2020-01-30               Kerala        0       0          1
# 1     2020-01-31               Kerala        0       0          1
# 2     2020-02-01               Kerala        0       0          2
# 3     2020-02-02               Kerala        0       0          3
# 4     2020-02-03               Kerala        0       0          3
# ...          ...                  ...      ...     ...        ...
# 18105 2021-08-11            Telangana   638410    3831     650353
# 18106 2021-08-11              Tripura    77811     773      80660
# 18107 2021-08-11          Uttarakhand   334650    7368     342462
# 18108 2021-08-11        Uttar Pradesh  1685492   22775    1708812
# 18109 2021-08-11          West Bengal  1506532   18252    1534999
#
#        Active_Cases
# 0                 1
# 1                 1
# 2                 2
# 3                 3
# 4                 3
# ...             ...
# 18105          8112
# ...

# %%
statewise=pd.pivot_table(covid_df,values=["Confirmed","Deaths","Cured",],index="State/UnionTerritory",aggfunc=max)

# %%
statewise
# Out:
#                                           Confirmed    Cured  Deaths
# State/UnionTerritory
# Andaman and Nicobar Islands                    7548     7412     129
# Andhra Pradesh                              1985182  1952736   13564
# Arunachal Pradesh                             50605    47821     248
# Assam                                        576149   559684    5420
# Bihar                                        725279   715352    9646
# Bihar****                                    715730   701234    9452
# Cases being reassigned to states               9265        0       0
# Chandigarh                                    61992    61150     811
# Chhattisgarh                                1003356   988189   13544
# Dadra and Nagar Haveli                        10377    10261       4
# Dadra and Nagar Haveli and Daman and Diu      10654    10646       4
# Daman & Diu                                       2        0       0
# ...

# %%
statewise["Recovery Rate"]=statewise["Cured"]*100/statewise["Confirmed"]

# %%
statewise["Mortality Rate"]=statewise["Deaths"]*100/statewise["Confirmed"]

# %%
statewise=statewise.sort_values(by="Confirmed",ascending=False)

# %%
statewise.style.background_gradient(cmap='cubehelix')
# Out:
# <style type="text/css">
# #T_dec9a_row0_col0, #T_dec9a_row0_col1, #T_dec9a_row0_col2, #T_dec9a_row20_col4, #T_dec9a_row39_col3 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_dec9a_row0_col3, #T_dec9a_row31_col3 {
#   background-color: #f0fbf5;
#   color: #000000;
# }
# #T_dec9a_row0_col4 {
#   background-color: #c3bff2;
#   color: #000000;
# }
# #T_dec9a_row1_col0, #T_dec9a_row3_col3, #T_dec9a_row4_col3, #T_dec9a_row5_col3, #T_dec9a_row24_col3, #T_dec9a_row27_col3, #T_dec9a_row28_col3, #T_dec9a_row29_col3 {
#   background-color: #f6fcf8;
#   color: #000000;
# }
# #T_dec9a_row1_col1, #T_dec9a_row1_col2, #T_dec9a_row20_col3, #T_dec9a_row26_col3 {
#   background-color: #f4fcf7;
#   color: #000000;
# }
# #T_dec9a_row1_col3 {
#   background-color: #effaf4;
#   color: #000000;
# }
# #T_dec9a_row1_col4 {
#   background-color: #c4bdf1;
#   color: #000000;
# }
# #T_dec9a_row2_col0 {
#   background-color: #c57a76;
#   color: #f1f1f1;
# }
# #T_dec9a_row2_col1 {
# ...

# %%
# top 10 active cases
top_10_active_states=covid_df.groupby(by='State/UnionTerritory').max()[['Active_Cases','Date']].sort_values(by=['Active_Cases'],ascending=False).reset_index()

# %%
fig=plt.figure(figsize=(16,9))

# %%
plt.title('Top 10 states with most active states in india',size=25)
# Out:
# Text(0.5, 1.0, 'Top 10 states with most active states in india')

# %%
ax=sns.barplot(data=top_10_active_states.iloc[:10],y="Active_Cases",x="State/UnionTerritory",linewidth=2,edgecolor="black")

# %%
#  top 10 active cases
top_10_active_states=covid_df.groupby(by='State/UnionTerritory').max()[['Active_Cases','Date']].sort_values(by=['Active_Cases'],ascending=False).reset_index()
fig=plt.figure(figsize=(12,7))
ax=sns.barplot(data=top_10_active_states.iloc[:10],y="Active_Cases",x="State/UnionTerritory",linewidth=2,edgecolor="black",)
plt.title('Top 10 states with most active states in india',size=25)
plt.xlabel("States")
plt.ylabel("Total Active Cases")

plt.show()

# %%
# Top states with highest Deaths
Top_10_deaths=covid_df.groupby(by='State/UnionTerritory').max()[['Deaths','Date']].sort_values(by=['Deaths'],ascending=False).reset_index()
fig=plt.figure(figsize=(18,5))
plt.title("Top 10 states with most deaths",size=25)
ax=sns.barplot(data=Top_10_deaths.iloc[:12],y="Deaths",x="State/UnionTerritory",linewidth=2,edgecolor="black")
plt.xlabel("States")
plt.ylabel("Total Death Cases")
# Out:
# Text(0, 0.5, 'Total Death Cases')

# %%
fig=plt.figure(figsize=(12,6))
ax=sns.lineplot(data=covid_df[covid_df['State/UnionTerritory'].isin(['Maharashtra','Karnataka','Tamil Nadu','Uttar Pradesh','Kerala'])],x='Date',y='Active_Cases',hue='State/UnionTerritory')
ax.set_title("Top Affected States in India ",size=16)
# Out:
# Text(0.5, 1.0, 'Top Affected States in India ')

# %%
vaccine_df.rename(columns={'Updated On':'Vaccine Date'},inplace=True)

# %%
vaccine_df
# Out:
#      Vaccine Date        State  Total Doses Administered  Sessions   Sites   \
# 0      16/01/2021        India                   48276.0    3455.0   2957.0
# 1      17/01/2021        India                   58604.0    8532.0   4954.0
# 2      18/01/2021        India                   99449.0   13611.0   6583.0
# 3      19/01/2021        India                  195525.0   17855.0   7951.0
# 4      20/01/2021        India                  251280.0   25472.0  10504.0
# ...           ...          ...                       ...       ...      ...
# 7840   11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841   12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842   13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843   14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844   15/08/2021  West Bengal                       NaN       NaN      NaN
#
# ...

# %%
vaccine_df.isnull().sum()
# Out:
# Vaccine Date                              0
# State                                     0
# Total Doses Administered                224
# Sessions                                224
#  Sites                                  224
# First Dose Administered                 224
# Second Dose Administered                224
# Male (Doses Administered)               384
# Female (Doses Administered)             384
# Transgender (Doses Administered)        384
#  Covaxin (Doses Administered)           224
# CoviShield (Doses Administered)         224
# Sputnik V (Doses Administered)         4850
# AEFI                                   2407
# 18-44 Years (Doses Administered)       6143
# 45-60 Years (Doses Administered)       6143
# 60+ Years (Doses Administered)         6143
# 18-44 Years(Individuals Vaccinated)    4112
# 45-60 Years(Individuals Vaccinated)    4111
# 60+ Years(Individuals Vaccinated)      4111
# Male(Individuals Vaccinated)           7685
# ...

# %%
vaccination=vaccine_df.drop(columns=['Sputnik V (Doses Administered)','AEFI','18-44 Years (Doses Administered)','45-60 Years (Doses Administered)','60+ Years (Doses Administered)'],axis=1)

# %%
vaccination.tail()
# Out:
#      Vaccine Date        State  Total Doses Administered  Sessions   Sites   \
# 7840   11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841   12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842   13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843   14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844   15/08/2021  West Bengal                       NaN       NaN      NaN
#
#       First Dose Administered  Second Dose Administered  \
# 7840                      NaN                       NaN
# 7841                      NaN                       NaN
# 7842                      NaN                       NaN
# 7843                      NaN                       NaN
# 7844                      NaN                       NaN
#
#       Male (Doses Administered)  Female (Doses Administered)  \
# 7840                        NaN                          NaN
# ...

# %%
# male vs female vaccination

# %%
male=vaccination["Male(Individuals Vaccinated)"].sum()
female=vaccination['Female(Individuals Vaccinated)'].sum()
plot=px.pie(names=["Male","Female"],values=[male,female],title="Male and Female Vaccination")

# %%
vaccine=vaccine_df[vaccine_df.State!='India']
vaccine
# Out:
#      Vaccine Date                        State  Total Doses Administered  \
# 212    16/01/2021  Andaman and Nicobar Islands                      23.0
# 213    17/01/2021  Andaman and Nicobar Islands                      23.0
# 214    18/01/2021  Andaman and Nicobar Islands                      42.0
# 215    19/01/2021  Andaman and Nicobar Islands                      89.0
# 216    20/01/2021  Andaman and Nicobar Islands                     124.0
# ...           ...                          ...                       ...
# 7840   11/08/2021                  West Bengal                       NaN
# 7841   12/08/2021                  West Bengal                       NaN
# 7842   13/08/2021                  West Bengal                       NaN
# 7843   14/08/2021                  West Bengal                       NaN
# 7844   15/08/2021                  West Bengal                       NaN
#
#       Sessions   Sites   First Dose Administered  Second Dose Administered  \
# ...

# %%
vaccine.rename(columns={"Total Individuals Vaccinated":"Total"},inplace=True)
vaccine.head()
# Out:
# C:\python39\lib\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#     Vaccine Date                        State  Total Doses Administered  \
# 212   16/01/2021  Andaman and Nicobar Islands                      23.0
# 213   17/01/2021  Andaman and Nicobar Islands                      23.0
# 214   18/01/2021  Andaman and Nicobar Islands                      42.0
# 215   19/01/2021  Andaman and Nicobar Islands                      89.0
# 216   20/01/2021  Andaman and Nicobar Islands                     124.0
#
#      Sessions   Sites   First Dose Administered  Second Dose Administered  \
# 212       2.0      2.0                     23.0                       0.0
# 213       2.0      2.0                     23.0                       0.0
# ...

# %%
 #most vaccinated state

# %%
max_vac=vaccine.groupby('State')['Total'].sum().to_frame('Total')
max_vac=max_vac.sort_values('Total',ascending=False)[:5]
min_vac=vaccine.groupby('State')['Total'].sum().to_frame('Total')
min_vac=min_vac.sort_values('Total')[:5]
min_vac=min_vac.sort_values('Total',ascending=False)
min_vac
# Out:
#                                                Total
# State
# Sikkim                                    16136752.0
# Dadra and Nagar Haveli and Daman and Diu  11358600.0
# Ladakh                                     9466289.0
# Andaman and Nicobar Islands                8102125.0
# Lakshadweep                                2124715.0

# %%
fig=plt.figure(figsize=(10,5))
plt.title("Top 5 Vaccinated States in India",size=20)
x=sns.barplot(data=max_vac.iloc[:10],y=max_vac.Total,x=max_vac.index,linewidth=2,edgecolor="black")
plt.xlabel("States")
plt.ylabel("Vaccination")
plt.show()

# %%
fig=plt.figure(figsize=(14,5))
plt.title("Top 5 least Vaccinated States in India",size=20)
x=sns.barplot(data=min_vac.iloc[:5],y=min_vac.Total,x=min_vac.index,linewidth=2,edgecolor="black")
plt.xlabel("States")
plt.ylabel("Vaccination")
plt.show()
py.plot(fig,filename="Top Vaccinated states",auto_open=True)
# Out:
# ---------------------------------------------------------------------------
# PlotlyError                               Traceback (most recent call last)
# Input In [44], in <module>
#       5 plt.ylabel("Vaccination")
#       6 plt.show()
# ----> 7 py.plot(fig,filename="Top Vaccinated states",auto_open=True)
#
# File C:\python39\lib\site-packages\chart_studio\plotly\plotly.py:197, in plot(figure_or_data, validate, **plot_options)
#     167 """Create a unique url for this plot in Plotly and optionally open url.
#     168
#     169 plot_options keyword arguments:
#    (...)
#     193
#     194 """
#     195 import plotly.tools
# --> 197 figure = plotly.tools.return_figure_from_figure_or_data(figure_or_data, validate)
#     198 for entry in figure["data"]:
#     199     if ("type" in entry) and (entry["type"] == "scattergl"):
#
# File C:\python39\lib\site-packages\plotly\tools.py:544, in return_figure_from_figure_or_data(figure_or_data, validate_figure)
#     542     validated = True
# ...

# %%
covid_df
# Out:
#             Date State/UnionTerritory    Cured  Deaths  Confirmed  \
# 0     2020-01-30               Kerala        0       0          1
# 1     2020-01-31               Kerala        0       0          1
# 2     2020-02-01               Kerala        0       0          2
# 3     2020-02-02               Kerala        0       0          3
# 4     2020-02-03               Kerala        0       0          3
# ...          ...                  ...      ...     ...        ...
# 18105 2021-08-11            Telangana   638410    3831     650353
# 18106 2021-08-11              Tripura    77811     773      80660
# 18107 2021-08-11          Uttarakhand   334650    7368     342462
# 18108 2021-08-11        Uttar Pradesh  1685492   22775    1708812
# 18109 2021-08-11          West Bengal  1506532   18252    1534999
#
#        Active_Cases
# 0                 1
# 1                 1
# 2                 2
# 3                 3
# 4                 3
# ...             ...
# 18105          8112
# ...

# %%
vaccination
# Out:
#      Vaccine Date        State  Total Doses Administered  Sessions   Sites   \
# 0      16/01/2021        India                   48276.0    3455.0   2957.0
# 1      17/01/2021        India                   58604.0    8532.0   4954.0
# 2      18/01/2021        India                   99449.0   13611.0   6583.0
# 3      19/01/2021        India                  195525.0   17855.0   7951.0
# 4      20/01/2021        India                  251280.0   25472.0  10504.0
# ...           ...          ...                       ...       ...      ...
# 7840   11/08/2021  West Bengal                       NaN       NaN      NaN
# 7841   12/08/2021  West Bengal                       NaN       NaN      NaN
# 7842   13/08/2021  West Bengal                       NaN       NaN      NaN
# 7843   14/08/2021  West Bengal                       NaN       NaN      NaN
# 7844   15/08/2021  West Bengal                       NaN       NaN      NaN
#
# ...

# %%
vaccine

# %%
import chart_studio
chart_studio.tools.set_credentials_file(username='meenal123',api_key='MppC05TMaULqzlyU8UVO')

# %%
import chart_studio.plotly as py
import chart_studio.tools as tls
